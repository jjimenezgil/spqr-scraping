# %%
import pandas as pd
import re

# %%
df = pd.read_csv("../dataset/sources.csv")

# %%
df
# Out:
#                   author                                              title  \
# 0              Aeschylus                                          Agamemnon
# 1      M. Tullius Cicero  Speech before Roman Citizens on Behalf of Gaiu...
# 2      M. Tullius Cicero  Orations, The fourteen orations against Marcus...
# 3      M. Tullius Cicero                                            Letters
# 4      M. Tullius Cicero                              Laelius on friendship
# 5      M. Tullius Cicero                                         Divination
# 6      M. Tullius Cicero                         De Senectute: introduction
# 7      M. Tullius Cicero         De Officiis: introduction and bibliography
# 8      M. Tullius Cicero                                 De Officiis: index
# 9      M. Tullius Cicero                                        De Officiis
# 10     M. Tullius Cicero                       De Divinatione: introduction
# ...

# %%
df_dict = df.to_dict(orient="records")

# %%
df_dict[0]["test_content"]
# Out:
# "[1]\n  Release from this weary task of mine has been my plea to the gods throughout this long year's watch, in which, lying upon the palace roof of the Atreidae, upon my bent arm, like a dog, I have learned to know well the gathering of the night's stars, those radiant potentates conspicuous in the firmament,\n    [5]\n  bringers of winter and summer to mankind [the constellations, when they rise and set].,So now I am still watching for the signal-flame, the gleaming fire that is to bring news from,Troy,and\n    [10]\n  tidings of its capture.  For thus commands my queen, woman in passionate heart and man in strength of purpose.  And whenever I make here my bed, restless and dank with dew and unvisited by dreams—for instead of sleep fear stands ever by my side,\n    [15]\n  so that I cannot close my eyelids fast in sleep—and whenever I care to sing or hum （and thus apply an antidote of song to ward off drowsiness）, then my tears start forth, as I bewail the fortunes of this house of
# ...
